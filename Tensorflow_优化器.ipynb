# %% [markdown]
# <a href="https://colab.research.google.com/github/IamMarking/Tensorflow/blob/master/Tensorflow_%E4%BC%98%E5%8C%96%E5%99%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 优化器学习

# %% [markdown]
# - 标准梯度下降法  所有样本
# - 随机梯度下降法 单个样本
# - 批量梯度下降法 按比例抽取

# %% [markdown]
# - SGD
# - Momentum
# - NAG
# -
